# %%
import os

import pandas as pd
import torch

# %%
from dotenv import load_dotenv

# 현재 작업 디렉토리 가져오기
current_dir = os.getcwd()  # 현재 Jupyter Notebook의 작업 디렉토
env_path = os.path.join(current_dir, '../.env')

# .env 파일 로드
load_dotenv(env_path)
# Out:
# True

# %%
db_path=os.getenv("DATA_PATH")
ecg_data=pd.read_csv(f'{db_path}/ptbxl_database.csv')
ecg_data.head()
# Out:
#    ecg_id  patient_id   age  sex  height  weight  nurse  site     device  \
# 0       1     15709.0  56.0    1     NaN    63.0    2.0   0.0  CS-12   E
# 1       2     13243.0  19.0    0     NaN    70.0    2.0   0.0  CS-12   E
# 2       3     20372.0  37.0    1     NaN    69.0    2.0   0.0  CS-12   E
# 3       4     17014.0  24.0    0     NaN    82.0    2.0   0.0  CS-12   E
# 4       5     17448.0  19.0    1     NaN    70.0    2.0   0.0  CS-12   E
#
#         recording_date  ... validated_by_human  baseline_drift static_noise  \
# 0  1984-11-09 09:17:34  ...               True             NaN    , I-V1,
# 1  1984-11-14 12:55:37  ...               True             NaN          NaN
# 2  1984-11-15 12:49:10  ...               True             NaN          NaN
# 3  1984-11-15 13:44:57  ...               True    , II,III,AVF          NaN
# 4  1984-11-17 10:43:15  ...               True   , III,AVR,AVF          NaN
#
#   burst_noise electrodes_problems  extra_beats  pacemaker  strat_fold  \
# 0         NaN                 NaN          NaN        NaN           3
# 1         NaN                 NaN          NaN        NaN           2
# 2         NaN                 NaN          NaN        NaN           5
# 3         NaN                 NaN          NaN        NaN           3
# 4         NaN                 NaN          NaN        NaN           4
#
#                  filename_lr                filename_hr
# 0  records100/00000/00001_lr  records500/00000/00001_hr
# 1  records100/00000/00002_lr  records500/00000/00002_hr
# 2  records100/00000/00003_lr  records500/00000/00003_hr
# 3  records100/00000/00004_lr  records500/00000/00004_hr
# 4  records100/00000/00005_lr  records500/00000/00005_hr
#
# [5 rows x 28 columns]

# %% [markdown]
# ## 모델 및 하이퍼파라미터 준비
# BCResNet의 cnn_first의 stride나 다른 conv의 stride에 따라 입력 또는 출력의 크기가 달라짐.
# 이는 조절해가면서 실험필요

# %%
from ver5_journal.common.network.BCResNets import BCResNets

tau = 1
in_channel = 12
model = BCResNets(int(tau * 8), 5, in_channel)

if in_channel == 1:
    sample = torch.randn(1,12,1000)
else:
    sample = torch.randn(1,12,1000)
    #sample = torch.randn(1,12,20,48)

print(sample.shape)
pred = model(sample)
pred.shape
# Out:
# torch.Size([1, 12, 1000])
# torch.Size([1, 5])

# %%
from ver5_journal.common.data.create_final_data import create_final_data
from ver5_journal.common.data.ECG_Data import ECG_Data
from sklearn.metrics import roc_auc_score, accuracy_score
import torch
from torch.utils.data import DataLoader
import numpy as np
from ver5_journal.common.network.BCResNets import BCResNets

# 레이블 순서 : 데이터가 많은 순
label_columns = ['NORM', 'MI', 'STTC', 'CD', 'HYP']
num_epochs = 100

# train/val/test 분리
final_data = create_final_data()
ECG_train = final_data[final_data['strat_fold'].isin([1, 2, 3, 4, 5, 6, 7, 8])].reset_index(drop=True)
ECG_val = final_data[final_data['strat_fold'] == 9].reset_index(drop=True)
ECG_test = final_data[final_data['strat_fold'] == 10].reset_index(drop=True)

# Training 함수 정의
def train_one_epoch(model, train_loader, optimizer, loss_fn, device, label_idx):
    model.train()
    train_loss = 0
    y_true = []
    y_pred = []

    for data, label in train_loader:
        data, label = data.to(device), label.to(device)
        optimizer.zero_grad()

        output = model(data)
        label_data = label[:, label_idx].float().to(device)  # (batch_size)로 맞춤

        loss = loss_fn(output.squeeze(-1), label_data)  # Sigmoid 제거
        loss.backward()
        optimizer.step()

        train_loss += loss.item()

        # Accuracy 계산을 위해 예측값 저장
        y_true.extend(label_data.cpu().numpy())
        y_pred.extend((torch.sigmoid(output).detach().cpu().numpy() > 0.5).astype(int))  # 임계값 0.5 적용
    
    avg_loss = train_loss / len(train_loader)
    train_accuracy = accuracy_score(np.array(y_true), np.array(y_pred))  # 정확도 계산
    return avg_loss, train_accuracy

# Validation 함수 정의
def validate_one_epoch(model, val_loader, loss_fn, device, label_idx):
    model.eval()
    val_loss = 0
    y_true = []
    y_pred = []

    with torch.no_grad():
        for data, label in val_loader:
            data, label = data.to(device), label.to(device)

            output = model(data)
            label_data = label[:, label_idx].float().to(device)  # (batch_size)로 맞춤
            loss = loss_fn(output.squeeze(-1), label_data)  # Sigmoid 제거
            val_loss += loss.item()

            # AUC 및 Accuracy 계산을 위한 예측값 저장
            y_true.extend(label_data.cpu().numpy())
            y_pred.extend(torch.sigmoid(output).detach().cpu().numpy())

    avg_val_loss = val_loss / len(val_loader)
    val_auc = roc_auc_score(y_true, y_pred)
    val_accuracy = accuracy_score(np.array(y_true), (np.array(y_pred) > 0.5).astype(int))  # 정확도 계산
    return avg_val_loss, val_auc, val_accuracy

# 데이터셋의 0과 1 비율에 맞춘 가중치 계산 함수
def calculate_class_weight(dataset, label_idx):
    labels = dataset[:, label_idx]  # 넘파이 배열에 맞게 인덱스로 접근
    num_ones = np.sum(labels == 1)
    num_zeros = np.sum(labels == 0)
    
    # 가중치 계산 (1의 개수가 0인 경우 대비)
    if num_ones == 0:
        weight = 1.0  # 1이 없는 경우 가중치 1로 설정
    else:
        weight = num_zeros / num_ones  # 가중치 
    print (f'num_zeros: {num_zeros}, num_ones: {num_ones}')
    print(f'weight: {weight: .4f}')    
    return weight

# %%
# 모델 학습 루프
for i, label in enumerate(label_columns):
    print(f"Training model for label: {label}")
    
    # 각 레이블에 대해 데이터 추출
    ECG_train_label = ECG_train[ECG_train[label].isin([0, 1])].reset_index(drop=True)
    ECG_val_label = ECG_val[ECG_val[label].isin([0, 1])].reset_index(drop=True)
    # ECG_test_label = ECG_test[ECG_test[label].isin([0, 1])].reset_index(drop=True)

    # 데이터 로더 준비
    train_dataset_label = ECG_Data(ECG_train_label)
    train_loader_label = DataLoader(train_dataset_label, batch_size=32, shuffle=True)

    val_dataset_label = ECG_Data(ECG_val_label)
    val_loader_label = DataLoader(val_dataset_label, batch_size=32, shuffle=True)

    # 모델 정의 및 학습
    device = torch.device("mps" if torch.backends.mps.is_available() else "cpu")
    model = BCResNets(16, 1, in_channel=12).to(device)

    optim = torch.optim.Adam(model.parameters(), lr=1e-2)
    weight = calculate_class_weight(ECG_train[label_columns].values, i)

    # Weighted BCEWithLogitsLoss 설정
    loss_fn = torch.nn.BCEWithLogitsLoss(pos_weight=torch.tensor([weight], dtype=torch.float32).to(device))
    # loss_fn = torch.nn.BCELoss()

    best_val_auc = float('-inf')
    model_path = f'../common/weight_BCE_models/{label}_model.pth'
    label_idx = label_columns.index(label)

    for epoch in range(num_epochs):
        # Training 단계
        train_loss, train_accuracy = train_one_epoch(model, train_loader_label, optim, loss_fn, device, label_idx)
        
        # Validation 단계
        val_loss, val_auc, val_accuracy = validate_one_epoch(model, val_loader_label, loss_fn, device,label_idx)
        
        print(f'Epoch {epoch+1}/{num_epochs}, Train Loss: {train_loss:.4f}, Train Accuracy: {train_accuracy:.4f}')
        print(f'Epoch {epoch+1}/{num_epochs}, Val Loss: {val_loss:.4f}, Val AUC: {val_auc:.4f}, Val Accuracy: {val_accuracy:.4f}')
        
        # 최적 AUC 모델 저장
        if val_auc > best_val_auc:
            best_val_auc = val_auc
            torch.save(model.state_dict(), model_path)
            print(f"Best model saved for label {label} with AUC {best_val_auc:.4f}")

    print(f"Training completed for label: {label}. Best AUC: {best_val_auc:.4f}")
    print("=====================================================================")
# Out:
# Training model for label: NORM
# num_zeros: 9822, num_ones: 7596
# weight:  1.2930
# Epoch 1/100, Train Loss: 0.5215, Train Accuracy: 0.7808
# Epoch 1/100, Val Loss: 0.4840, Val AUC: 0.9123, Val Accuracy: 0.7952
# Best model saved for label NORM with AUC 0.9123
# Epoch 2/100, Train Loss: 0.4316, Train Accuracy: 0.8297
# Epoch 2/100, Val Loss: 0.4480, Val AUC: 0.9209, Val Accuracy: 0.8108
# Best model saved for label NORM with AUC 0.9209
# Epoch 3/100, Train Loss: 0.3998, Train Accuracy: 0.8407
# Epoch 3/100, Val Loss: 0.3999, Val AUC: 0.9268, Val Accuracy: 0.8484
# Best model saved for label NORM with AUC 0.9268
# Epoch 4/100, Train Loss: 0.3862, Train Accuracy: 0.8492
# Epoch 4/100, Val Loss: 0.4387, Val AUC: 0.9271, Val Accuracy: 0.8438
# Best model saved for label NORM with AUC 0.9271
# Epoch 5/100, Train Loss: 0.3784, Train Accuracy: 0.8515
# Epoch 5/100, Val Loss: 0.4406, Val AUC: 0.9257, Val Accuracy: 0.8429
# Epoch 6/100, Train Loss: 0.3746, Train Accuracy: 0.8536
# Epoch 6/100, Val Loss: 0.4255, Val AUC: 0.9238, Val Accuracy: 0.8346
# Epoch 7/100, Train Loss: 0.3749, Train Accuracy: 0.8532
# Epoch 7/100, Val Loss: 0.4423, Val AUC: 0.9278, Val Accuracy: 0.8443
# Best model saved for label NORM with AUC 0.9278
# Epoch 8/100, Train Loss: 0.3706, Train Accuracy: 0.8545
# Epoch 8/100, Val Loss: 0.4112, Val AUC: 0.9270, Val Accuracy: 0.8488
# Epoch 9/100, Train Loss: 0.3570, Train Accuracy: 0.8624
# Epoch 9/100, Val Loss: 0.3860, Val AUC: 0.9336, Val Accuracy: 0.8534
# Best model saved for label NORM with AUC 0.9336
# Epoch 10/100, Train Loss: 0.3569, Train Accuracy: 0.8614
# Epoch 10/100, Val Loss: 0.3687, Val AUC: 0.9337, Val Accuracy: 0.8571
# Best model saved for label NORM with AUC 0.9337
# Epoch 100/100, Val Loss: 0.3559, Val AUC: 0.9422, Val Accuracy: 0.8681
# Training completed for label: NORM. Best AUC: 0.9448
# =====================================================================
# Training model for label: MI
# num_zeros: 13039, num_ones: 4379
# weight:  2.9776
# Epoch 1/100, Train Loss: 0.9217, Train Accuracy: 0.6656
# Epoch 1/100, Val Loss: 0.8945, Val AUC: 0.8446, Val Accuracy: 0.8163
# Best model saved for label MI with AUC 0.8446
# Epoch 2/100, Train Loss: 0.7255, Train Accuracy: 0.7700
# Epoch 2/100, Val Loss: 0.7020, Val AUC: 0.8728, Val Accuracy: 0.8158
# Best model saved for label MI with AUC 0.8728
# Epoch 3/100, Train Loss: 0.6516, Train Accuracy: 0.8002
# Epoch 3/100, Val Loss: 0.6671, Val AUC: 0.8960, Val Accuracy: 0.8465
# Best model saved for label MI with AUC 0.8960
# Epoch 4/100, Train Loss: 0.6154, Train Accuracy: 0.8147
# Epoch 4/100, Val Loss: 0.6265, Val AUC: 0.9046, Val Accuracy: 0.8255
# Best model saved for label MI with AUC 0.9046
# Epoch 5/100, Train Loss: 0.5890, Train Accuracy: 0.8237
# Epoch 5/100, Val Loss: 0.6427, Val AUC: 0.9011, Val Accuracy: 0.7943
# Epoch 6/100, Train Loss: 0.5717, Train Accuracy: 0.8293
# Epoch 6/100, Val Loss: 0.6581, Val AUC: 0.9050, Val Accuracy: 0.8021
# Best model saved for label MI with AUC 0.9050
# Epoch 7/100, Train Loss: 0.5628, Train Accuracy: 0.8329
# Epoch 7/100, Val Loss: 0.6253, Val AUC: 0.9087, Val Accuracy: 0.8314
# Best model saved for label MI with AUC 0.9087
# Epoch 8/100, Train Loss: 0.5472, Train Accuracy: 0.8387
# Epoch 8/100, Val Loss: 0.5898, Val AUC: 0.9122, Val Accuracy: 0.8488
# Best model saved for label MI with AUC 0.9122
# Epoch 9/100, Train Loss: 0.5482, Train Accuracy: 0.8394
# Epoch 9/100, Val Loss: 0.6332, Val AUC: 0.9120, Val Accuracy: 0.8470
# Epoch 10/100, Train Loss: 0.5310, Train Accuracy: 0.8465
# Epoch 10/100, Val Loss: 0.6476, Val AUC: 0.9052, Val Accuracy: 0.8534
# Epoch 11/100, Train Loss: 0.5361, Train Accuracy: 0.8423
# Epoch 11/100, Val Loss: 0.5933, Val AUC: 0.9122, Val Accuracy: 0.7994
# Best model saved for label MI with AUC 0.9122
# Epoch 12/100, Train Loss: 0.5323, Train Accuracy: 0.8422
# Epoch 12/100, Val Loss: 0.6185, Val AUC: 0.9105, Val Accuracy: 0.8617
# Epoch 13/100, Train Loss: 0.5249, Train Accuracy: 0.8476
# Epoch 13/100, Val Loss: 0.5987, Val AUC: 0.9164, Val Accuracy: 0.8594
# Best model saved for label MI with AUC 0.9164
# Epoch 14/100, Train Loss: 0.5178, Train Accuracy: 0.8505
# Epoch 14/100, Val Loss: 0.5911, Val AUC: 0.9117, Val Accuracy: 0.8053
# Epoch 15/100, Train Loss: 0.5160, Train Accuracy: 0.8484
# Epoch 15/100, Val Loss: 0.6030, Val AUC: 0.9176, Val Accuracy: 0.8443
# Best model saved for label MI with AUC 0.9176
# Epoch 16/100, Train Loss: 0.5139, Train Accuracy: 0.8508
# Epoch 16/100, Val Loss: 0.5558, Val AUC: 0.9200, Val Accuracy: 0.8415
# Best model saved for label MI with AUC 0.9200
# Epoch 17/100, Train Loss: 0.5088, Train Accuracy: 0.8512
# Epoch 17/100, Val Loss: 0.5679, Val AUC: 0.9172, Val Accuracy: 0.8236
# Epoch 18/100, Train Loss: 0.5113, Train Accuracy: 0.8504
# Epoch 18/100, Val Loss: 0.5934, Val AUC: 0.9189, Val Accuracy: 0.7920
# Epoch 19/100, Train Loss: 0.5003, Train Accuracy: 0.8569
# Epoch 19/100, Val Loss: 0.5775, Val AUC: 0.9189, Val Accuracy: 0.8420
# Epoch 20/100, Train Loss: 0.4994, Train Accuracy: 0.8556
# Epoch 20/100, Val Loss: 0.5966, Val AUC: 0.9241, Val Accuracy: 0.8136
# Best model saved for label MI with AUC 0.9241
# Epoch 21/100, Train Loss: 0.4963, Train Accuracy: 0.8543
# Epoch 21/100, Val Loss: 0.5831, Val AUC: 0.9206, Val Accuracy: 0.8117
# Epoch 22/100, Train Loss: 0.4898, Train Accuracy: 0.8549
# Epoch 22/100, Val Loss: 0.5580, Val AUC: 0.9243, Val Accuracy: 0.8305
# Best model saved for label MI with AUC 0.9243
# Epoch 23/100, Train Loss: 0.4899, Train Accuracy: 0.8574
# Epoch 23/100, Val Loss: 0.5566, Val AUC: 0.9268, Val Accuracy: 0.8149
# Best model saved for label MI with AUC 0.9268
# Epoch 24/100, Train Loss: 0.4956, Train Accuracy: 0.8525
# Epoch 24/100, Val Loss: 0.5807, Val AUC: 0.9221, Val Accuracy: 0.8003
# Epoch 25/100, Train Loss: 0.4914, Train Accuracy: 0.8527
# Epoch 25/100, Val Loss: 0.6149, Val AUC: 0.9113, Val Accuracy: 0.8021
# Epoch 26/100, Train Loss: 0.4863, Train Accuracy: 0.8554
# Epoch 26/100, Val Loss: 0.5838, Val AUC: 0.9179, Val Accuracy: 0.8113
# Epoch 27/100, Train Loss: 0.4773, Train Accuracy: 0.8580
# Epoch 27/100, Val Loss: 0.5998, Val AUC: 0.9231, Val Accuracy: 0.7746
# Epoch 28/100, Train Loss: 0.4800, Train Accuracy: 0.8584
# Epoch 28/100, Val Loss: 0.5930, Val AUC: 0.9188, Val Accuracy: 0.8094
# Epoch 29/100, Train Loss: 0.4815, Train Accuracy: 0.8593
# Epoch 29/100, Val Loss: 0.5692, Val AUC: 0.9194, Val Accuracy: 0.8131
# Epoch 30/100, Train Loss: 0.4763, Train Accuracy: 0.8616
# Epoch 30/100, Val Loss: 0.5595, Val AUC: 0.9259, Val Accuracy: 0.8246
# Epoch 31/100, Train Loss: 0.4794, Train Accuracy: 0.8597
# Epoch 31/100, Val Loss: 0.5590, Val AUC: 0.9216, Val Accuracy: 0.8374
# Epoch 32/100, Train Loss: 0.4759, Train Accuracy: 0.8595
# Epoch 32/100, Val Loss: 0.5503, Val AUC: 0.9261, Val Accuracy: 0.8282
# Epoch 87/100, Train Loss: 0.4043, Train Accuracy: 0.8810
# Epoch 87/100, Val Loss: 0.5557, Val AUC: 0.9284, Val Accuracy: 0.8094
# Epoch 88/100, Train Loss: 0.4034, Train Accuracy: 0.8833
# Epoch 88/100, Val Loss: 0.5233, Val AUC: 0.9298, Val Accuracy: 0.8259
# Epoch 89/100, Train Loss: 0.3993, Train Accuracy: 0.8832
# Epoch 89/100, Val Loss: 0.5129, Val AUC: 0.9309, Val Accuracy: 0.8520
# Epoch 90/100, Train Loss: 0.4031, Train Accuracy: 0.8815
# Epoch 90/100, Val Loss: 0.5295, Val AUC: 0.9315, Val Accuracy: 0.8227
# Best model saved for label MI with AUC 0.9315
# Epoch 91/100, Train Loss: 0.4039, Train Accuracy: 0.8822
# Epoch 91/100, Val Loss: 0.5349, Val AUC: 0.9292, Val Accuracy: 0.8122
# Epoch 92/100, Train Loss: 0.4004, Train Accuracy: 0.8824
# Epoch 92/100, Val Loss: 0.5485, Val AUC: 0.9316, Val Accuracy: 0.7902
# Best model saved for label MI with AUC 0.9316
# Epoch 93/100, Train Loss: 0.4062, Train Accuracy: 0.8813
# Epoch 93/100, Val Loss: 0.5676, Val AUC: 0.9269, Val Accuracy: 0.8026
# Epoch 94/100, Train Loss: 0.4059, Train Accuracy: 0.8814
# Epoch 94/100, Val Loss: 0.5368, Val AUC: 0.9305, Val Accuracy: 0.8136
# Epoch 95/100, Train Loss: 0.4002, Train Accuracy: 0.8804
# Epoch 95/100, Val Loss: 0.5197, Val AUC: 0.9312, Val Accuracy: 0.8264
# Epoch 96/100, Train Loss: 0.3903, Train Accuracy: 0.8850
# Epoch 96/100, Val Loss: 0.5110, Val AUC: 0.9292, Val Accuracy: 0.8310
# Epoch 97/100, Train Loss: 0.4006, Train Accuracy: 0.8836
# Epoch 97/100, Val Loss: 0.5482, Val AUC: 0.9293, Val Accuracy: 0.7984
# Epoch 98/100, Train Loss: 0.4000, Train Accuracy: 0.8819
# Epoch 98/100, Val Loss: 0.5201, Val AUC: 0.9306, Val Accuracy: 0.8392
# Epoch 99/100, Train Loss: 0.4047, Train Accuracy: 0.8787
# Epoch 99/100, Val Loss: 0.5298, Val AUC: 0.9293, Val Accuracy: 0.8177
# Epoch 100/100, Train Loss: 0.4045, Train Accuracy: 0.8787
# Epoch 100/100, Val Loss: 0.5193, Val AUC: 0.9294, Val Accuracy: 0.8218
# Training completed for label: MI. Best AUC: 0.9316
# =====================================================================
# Training model for label: STTC
# num_zeros: 13331, num_ones: 4087
# weight:  3.2618
# Epoch 1/100, Train Loss: 0.8247, Train Accuracy: 0.7281
# Epoch 1/100, Val Loss: 0.7201, Val AUC: 0.9038, Val Accuracy: 0.7018
# Best model saved for label STTC with AUC 0.9038
# Epoch 2/100, Train Loss: 0.6712, Train Accuracy: 0.7876
# Epoch 2/100, Val Loss: 0.6593, Val AUC: 0.9135, Val Accuracy: 0.7797
# Best model saved for label STTC with AUC 0.9135
# Epoch 3/100, Train Loss: 0.6298, Train Accuracy: 0.8019
# Epoch 3/100, Val Loss: 0.6077, Val AUC: 0.9210, Val Accuracy: 0.8346
# Best model saved for label STTC with AUC 0.9210
# Epoch 4/100, Train Loss: 0.6150, Train Accuracy: 0.8080
# Epoch 4/100, Val Loss: 0.6397, Val AUC: 0.9134, Val Accuracy: 0.8488
# Epoch 5/100, Train Loss: 0.6018, Train Accuracy: 0.8151
# Epoch 5/100, Val Loss: 0.6529, Val AUC: 0.9158, Val Accuracy: 0.7531
# Epoch 6/100, Train Loss: 0.5919, Train Accuracy: 0.8171
# Epoch 6/100, Val Loss: 0.6045, Val AUC: 0.9219, Val Accuracy: 0.8360
# Best model saved for label STTC with AUC 0.9219
# Epoch 7/100, Train Loss: 0.5825, Train Accuracy: 0.8245
# Epoch 7/100, Val Loss: 0.5739, Val AUC: 0.9263, Val Accuracy: 0.8397
# Best model saved for label STTC with AUC 0.9263
# Epoch 8/100, Train Loss: 0.5836, Train Accuracy: 0.8223
# Epoch 8/100, Val Loss: 0.5700, Val AUC: 0.9269, Val Accuracy: 0.8630
# Best model saved for label STTC with AUC 0.9269
# Epoch 9/100, Train Loss: 0.5717, Train Accuracy: 0.8282
# Epoch 9/100, Val Loss: 0.6642, Val AUC: 0.9199, Val Accuracy: 0.8305
# Epoch 10/100, Train Loss: 0.5809, Train Accuracy: 0.8243
# Epoch 10/100, Val Loss: 0.6425, Val AUC: 0.9244, Val Accuracy: 0.7320
# Epoch 11/100, Train Loss: 0.5754, Train Accuracy: 0.8244
# Epoch 11/100, Val Loss: 0.6556, Val AUC: 0.9252, Val Accuracy: 0.8685
# Epoch 12/100, Train Loss: 0.5634, Train Accuracy: 0.8301
# Epoch 12/100, Val Loss: 0.5546, Val AUC: 0.9318, Val Accuracy: 0.8617
# Best model saved for label STTC with AUC 0.9318
# Epoch 13/100, Train Loss: 0.5610, Train Accuracy: 0.8313
# Epoch 13/100, Val Loss: 0.6298, Val AUC: 0.9272, Val Accuracy: 0.8694
# Epoch 14/100, Train Loss: 0.5560, Train Accuracy: 0.8326
# Epoch 14/100, Val Loss: 0.6258, Val AUC: 0.9277, Val Accuracy: 0.8424
# Epoch 15/100, Train Loss: 0.5539, Train Accuracy: 0.8300
# Epoch 15/100, Val Loss: 0.5924, Val AUC: 0.9250, Val Accuracy: 0.8621
# Epoch 16/100, Train Loss: 0.5493, Train Accuracy: 0.8344
# Epoch 16/100, Val Loss: 0.5790, Val AUC: 0.9242, Val Accuracy: 0.7920
# Epoch 17/100, Train Loss: 0.5508, Train Accuracy: 0.8320
# Epoch 17/100, Val Loss: 0.6392, Val AUC: 0.9281, Val Accuracy: 0.8736
# Epoch 18/100, Train Loss: 0.5429, Train Accuracy: 0.8375
# Epoch 18/100, Val Loss: 0.5524, Val AUC: 0.9328, Val Accuracy: 0.8397
# Best model saved for label STTC with AUC 0.9328
# Epoch 19/100, Train Loss: 0.5449, Train Accuracy: 0.8345
# Epoch 19/100, Val Loss: 0.5680, Val AUC: 0.9298, Val Accuracy: 0.8305
# Epoch 20/100, Train Loss: 0.5363, Train Accuracy: 0.8391
# Epoch 92/100, Val Loss: 0.5362, Val AUC: 0.9338, Val Accuracy: 0.8704
# Epoch 93/100, Train Loss: 0.4600, Train Accuracy: 0.8655
# Epoch 93/100, Val Loss: 0.6003, Val AUC: 0.9317, Val Accuracy: 0.8887
# Epoch 94/100, Train Loss: 0.4578, Train Accuracy: 0.8624
# Epoch 94/100, Val Loss: 0.5664, Val AUC: 0.9294, Val Accuracy: 0.8727
# Epoch 95/100, Train Loss: 0.4547, Train Accuracy: 0.8696
# Epoch 95/100, Val Loss: 0.5631, Val AUC: 0.9330, Val Accuracy: 0.8754
# Epoch 96/100, Train Loss: 0.4529, Train Accuracy: 0.8690
# Epoch 96/100, Val Loss: 0.5348, Val AUC: 0.9360, Val Accuracy: 0.8658
# Epoch 97/100, Train Loss: 0.4494, Train Accuracy: 0.8682
# Epoch 97/100, Val Loss: 0.5790, Val AUC: 0.9312, Val Accuracy: 0.8676
# Epoch 98/100, Train Loss: 0.4547, Train Accuracy: 0.8671
# Epoch 98/100, Val Loss: 0.5881, Val AUC: 0.9354, Val Accuracy: 0.8791
# Epoch 99/100, Train Loss: 0.4508, Train Accuracy: 0.8673
# Epoch 99/100, Val Loss: 0.5433, Val AUC: 0.9353, Val Accuracy: 0.8717
# Epoch 100/100, Train Loss: 0.4502, Train Accuracy: 0.8673
# Epoch 100/100, Val Loss: 0.5958, Val AUC: 0.9321, Val Accuracy: 0.8786
# Training completed for label: STTC. Best AUC: 0.9375
# =====================================================================
# Training model for label: CD
# num_zeros: 13511, num_ones: 3907
# weight:  3.4582
# Epoch 1/100, Train Loss: 0.9028, Train Accuracy: 0.7323
# Epoch 1/100, Val Loss: 0.8082, Val AUC: 0.8645, Val Accuracy: 0.8630
# Best model saved for label CD with AUC 0.8645
# Epoch 2/100, Train Loss: 0.7219, Train Accuracy: 0.8051
# Epoch 2/100, Val Loss: 0.7231, Val AUC: 0.8907, Val Accuracy: 0.8012
# Best model saved for label CD with AUC 0.8907
# Epoch 3/100, Train Loss: 0.6660, Train Accuracy: 0.8212
# Epoch 3/100, Val Loss: 0.6959, Val AUC: 0.8951, Val Accuracy: 0.8649
# Best model saved for label CD with AUC 0.8951
# Epoch 4/100, Train Loss: 0.6285, Train Accuracy: 0.8322
# Epoch 4/100, Val Loss: 0.6652, Val AUC: 0.9038, Val Accuracy: 0.8630
# Best model saved for label CD with AUC 0.9038
# Epoch 5/100, Train Loss: 0.6088, Train Accuracy: 0.8404
# Epoch 5/100, Val Loss: 0.6428, Val AUC: 0.9150, Val Accuracy: 0.8273
# Best model saved for label CD with AUC 0.9150
# Epoch 6/100, Train Loss: 0.5767, Train Accuracy: 0.8519
# Epoch 6/100, Val Loss: 0.6664, Val AUC: 0.9114, Val Accuracy: 0.8722
# Epoch 7/100, Train Loss: 0.5661, Train Accuracy: 0.8538
# Epoch 7/100, Val Loss: 0.6288, Val AUC: 0.9193, Val Accuracy: 0.8420
# Best model saved for label CD with AUC 0.9193
# Epoch 8/100, Train Loss: 0.5678, Train Accuracy: 0.8536
# Epoch 8/100, Val Loss: 0.6394, Val AUC: 0.9157, Val Accuracy: 0.8736
# Epoch 9/100, Train Loss: 0.5669, Train Accuracy: 0.8543
# Epoch 9/100, Val Loss: 0.6451, Val AUC: 0.9039, Val Accuracy: 0.8062
# Epoch 10/100, Train Loss: 0.5518, Train Accuracy: 0.8589
# Epoch 10/100, Val Loss: 0.6155, Val AUC: 0.9232, Val Accuracy: 0.8649
# Best model saved for label CD with AUC 0.9232
# Epoch 11/100, Train Loss: 0.5488, Train Accuracy: 0.8605
# Epoch 11/100, Val Loss: 0.6202, Val AUC: 0.9198, Val Accuracy: 0.8346
# Epoch 12/100, Train Loss: 0.5408, Train Accuracy: 0.8636
# Epoch 12/100, Val Loss: 0.6038, Val AUC: 0.9150, Val Accuracy: 0.8456
# Epoch 13/100, Train Loss: 0.5448, Train Accuracy: 0.8618
# Epoch 13/100, Val Loss: 0.6295, Val AUC: 0.9229, Val Accuracy: 0.8323
# Epoch 14/100, Train Loss: 0.5402, Train Accuracy: 0.8628
# Epoch 14/100, Val Loss: 0.6297, Val AUC: 0.9217, Val Accuracy: 0.8301
# Epoch 15/100, Train Loss: 0.5377, Train Accuracy: 0.8661
# Epoch 15/100, Val Loss: 0.5905, Val AUC: 0.9225, Val Accuracy: 0.8685
# Epoch 16/100, Train Loss: 0.5387, Train Accuracy: 0.8606
# Epoch 16/100, Val Loss: 0.5924, Val AUC: 0.9230, Val Accuracy: 0.8809
# Epoch 17/100, Train Loss: 0.5286, Train Accuracy: 0.8663
# Epoch 17/100, Val Loss: 0.7097, Val AUC: 0.9219, Val Accuracy: 0.7320
# Epoch 18/100, Train Loss: 0.5204, Train Accuracy: 0.8677
# Epoch 18/100, Val Loss: 0.5933, Val AUC: 0.9281, Val Accuracy: 0.8694
# Best model saved for label CD with AUC 0.9281
# Epoch 19/100, Train Loss: 0.5218, Train Accuracy: 0.8674
# Epoch 19/100, Val Loss: 0.5757, Val AUC: 0.9261, Val Accuracy: 0.8502
# Epoch 20/100, Train Loss: 0.5171, Train Accuracy: 0.8680
# Epoch 20/100, Val Loss: 0.7623, Val AUC: 0.9264, Val Accuracy: 0.6569
# Epoch 21/100, Train Loss: 0.5146, Train Accuracy: 0.8660
# Epoch 21/100, Val Loss: 0.5880, Val AUC: 0.9298, Val Accuracy: 0.8484
# Best model saved for label CD with AUC 0.9298
# Epoch 22/100, Train Loss: 0.5062, Train Accuracy: 0.8719
# Epoch 22/100, Val Loss: 0.6062, Val AUC: 0.9286, Val Accuracy: 0.8204
# Epoch 23/100, Train Loss: 0.5103, Train Accuracy: 0.8729
# Epoch 23/100, Val Loss: 0.6491, Val AUC: 0.9263, Val Accuracy: 0.8058
# Epoch 24/100, Train Loss: 0.4993, Train Accuracy: 0.8739
# Epoch 24/100, Val Loss: 0.5866, Val AUC: 0.9273, Val Accuracy: 0.8461
# Epoch 25/100, Train Loss: 0.4972, Train Accuracy: 0.8722
# Epoch 25/100, Val Loss: 0.5803, Val AUC: 0.9242, Val Accuracy: 0.8433
# Epoch 26/100, Train Loss: 0.5028, Train Accuracy: 0.8696
# Epoch 26/100, Val Loss: 0.5848, Val AUC: 0.9269, Val Accuracy: 0.8488
# Epoch 27/100, Train Loss: 0.4954, Train Accuracy: 0.8736
# Epoch 27/100, Val Loss: 0.6012, Val AUC: 0.9300, Val Accuracy: 0.8094
# Best model saved for label CD with AUC 0.9300
# Epoch 28/100, Train Loss: 0.4985, Train Accuracy: 0.8750
# Epoch 28/100, Val Loss: 0.5676, Val AUC: 0.9289, Val Accuracy: 0.8424
# Epoch 29/100, Train Loss: 0.4896, Train Accuracy: 0.8787
# Epoch 29/100, Val Loss: 0.5821, Val AUC: 0.9311, Val Accuracy: 0.8635
# Best model saved for label CD with AUC 0.9311
# Epoch 30/100, Train Loss: 0.4847, Train Accuracy: 0.8787
# Epoch 30/100, Val Loss: 0.5815, Val AUC: 0.9289, Val Accuracy: 0.8131
# Epoch 31/100, Train Loss: 0.5028, Train Accuracy: 0.8724
# Epoch 31/100, Val Loss: 0.6288, Val AUC: 0.9267, Val Accuracy: 0.8177
# Epoch 32/100, Train Loss: 0.4832, Train Accuracy: 0.8793
# Epoch 32/100, Val Loss: 0.5686, Val AUC: 0.9311, Val Accuracy: 0.8369
# Epoch 33/100, Train Loss: 0.4888, Train Accuracy: 0.8790
# Epoch 33/100, Val Loss: 0.6796, Val AUC: 0.9286, Val Accuracy: 0.7421
# Epoch 34/100, Train Loss: 0.4852, Train Accuracy: 0.8782
# Epoch 34/100, Val Loss: 0.5641, Val AUC: 0.9260, Val Accuracy: 0.8713
# Epoch 35/100, Train Loss: 0.4820, Train Accuracy: 0.8786
# Epoch 35/100, Val Loss: 0.6406, Val AUC: 0.9282, Val Accuracy: 0.7792
# Epoch 36/100, Train Loss: 0.4757, Train Accuracy: 0.8802
# Epoch 36/100, Val Loss: 0.6766, Val AUC: 0.9228, Val Accuracy: 0.7481
# Epoch 37/100, Train Loss: 0.4776, Train Accuracy: 0.8770
# Epoch 37/100, Val Loss: 0.7119, Val AUC: 0.9300, Val Accuracy: 0.6890
# Epoch 38/100, Train Loss: 0.4774, Train Accuracy: 0.8795
# Epoch 38/100, Val Loss: 0.6064, Val AUC: 0.9297, Val Accuracy: 0.8122
# Epoch 39/100, Train Loss: 0.4704, Train Accuracy: 0.8807
# Epoch 39/100, Val Loss: 0.5575, Val AUC: 0.9359, Val Accuracy: 0.8777
# Best model saved for label CD with AUC 0.9359
# Epoch 40/100, Train Loss: 0.4751, Train Accuracy: 0.8828
# Epoch 40/100, Val Loss: 0.6087, Val AUC: 0.9316, Val Accuracy: 0.8154
# Epoch 41/100, Train Loss: 0.4678, Train Accuracy: 0.8831
# Epoch 41/100, Val Loss: 0.5880, Val AUC: 0.9328, Val Accuracy: 0.8443
# Epoch 42/100, Train Loss: 0.4634, Train Accuracy: 0.8858
# Epoch 42/100, Val Loss: 0.5691, Val AUC: 0.9328, Val Accuracy: 0.8378
# Epoch 43/100, Train Loss: 0.4607, Train Accuracy: 0.8841
# Epoch 43/100, Val Loss: 0.6166, Val AUC: 0.9329, Val Accuracy: 0.8039
# Epoch 94/100, Train Loss: 0.4098, Train Accuracy: 0.8967
# Epoch 94/100, Val Loss: 0.6938, Val AUC: 0.9307, Val Accuracy: 0.7114
# Epoch 95/100, Train Loss: 0.4124, Train Accuracy: 0.8977
# Epoch 95/100, Val Loss: 0.5927, Val AUC: 0.9284, Val Accuracy: 0.8131
# Epoch 96/100, Train Loss: 0.4049, Train Accuracy: 0.8967
# Epoch 96/100, Val Loss: 0.5369, Val AUC: 0.9294, Val Accuracy: 0.8621
# Epoch 97/100, Train Loss: 0.4122, Train Accuracy: 0.8953
# Epoch 97/100, Val Loss: 0.6337, Val AUC: 0.9282, Val Accuracy: 0.7732
# Epoch 98/100, Train Loss: 0.4086, Train Accuracy: 0.8947
# Epoch 98/100, Val Loss: 0.5957, Val AUC: 0.9342, Val Accuracy: 0.7829
# Epoch 99/100, Train Loss: 0.4006, Train Accuracy: 0.8963
# Epoch 99/100, Val Loss: 0.5434, Val AUC: 0.9348, Val Accuracy: 0.8328
# Epoch 100/100, Train Loss: 0.4061, Train Accuracy: 0.8957
# Epoch 100/100, Val Loss: 0.5571, Val AUC: 0.9297, Val Accuracy: 0.8365
# Training completed for label: CD. Best AUC: 0.9389
# =====================================================================
# Training model for label: HYP
# num_zeros: 15299, num_ones: 2119
# weight:  7.2199
# Epoch 1/100, Train Loss: 0.9280, Train Accuracy: 0.7442
# Epoch 1/100, Val Loss: 0.9191, Val AUC: 0.8750, Val Accuracy: 0.7810
# Best model saved for label HYP with AUC 0.8750
# Epoch 2/100, Train Loss: 0.7979, Train Accuracy: 0.7666
# Epoch 2/100, Val Loss: 0.8747, Val AUC: 0.8859, Val Accuracy: 0.8323
# Best model saved for label HYP with AUC 0.8859
# Epoch 3/100, Train Loss: 0.7748, Train Accuracy: 0.7734
# Epoch 3/100, Val Loss: 0.8958, Val AUC: 0.8808, Val Accuracy: 0.8465
# Epoch 4/100, Train Loss: 0.7561, Train Accuracy: 0.7832
# Epoch 4/100, Val Loss: 1.3186, Val AUC: 0.8252, Val Accuracy: 0.8869
# Epoch 5/100, Train Loss: 0.7482, Train Accuracy: 0.7889
# Epoch 5/100, Val Loss: 0.9413, Val AUC: 0.8662, Val Accuracy: 0.8612
# Epoch 6/100, Train Loss: 0.7459, Train Accuracy: 0.7930
# Epoch 6/100, Val Loss: 0.8346, Val AUC: 0.8729, Val Accuracy: 0.8012
# Epoch 7/100, Train Loss: 0.7352, Train Accuracy: 0.8061
# Epoch 7/100, Val Loss: 0.8855, Val AUC: 0.8849, Val Accuracy: 0.7879
# Epoch 8/100, Train Loss: 0.7320, Train Accuracy: 0.7975
# Epoch 8/100, Val Loss: 0.8284, Val AUC: 0.8796, Val Accuracy: 0.7590
# Epoch 9/100, Train Loss: 0.7193, Train Accuracy: 0.8051
# Epoch 9/100, Val Loss: 0.7898, Val AUC: 0.8983, Val Accuracy: 0.8218
# Best model saved for label HYP with AUC 0.8983
# Epoch 10/100, Train Loss: 0.7064, Train Accuracy: 0.8095
# Epoch 10/100, Val Loss: 0.7776, Val AUC: 0.8916, Val Accuracy: 0.7787
# Epoch 11/100, Train Loss: 0.7003, Train Accuracy: 0.8047
# Epoch 11/100, Val Loss: 0.7473, Val AUC: 0.9048, Val Accuracy: 0.8479
# Best model saved for label HYP with AUC 0.9048
# Epoch 12/100, Train Loss: 0.7085, Train Accuracy: 0.8158
# Epoch 12/100, Val Loss: 0.8329, Val AUC: 0.8939, Val Accuracy: 0.8823
# Epoch 13/100, Train Loss: 0.6990, Train Accuracy: 0.8195
# Epoch 13/100, Val Loss: 0.8186, Val AUC: 0.9011, Val Accuracy: 0.7810
# Epoch 14/100, Train Loss: 0.6880, Train Accuracy: 0.8148
# Epoch 14/100, Val Loss: 0.8262, Val AUC: 0.8915, Val Accuracy: 0.8685
# Epoch 15/100, Train Loss: 0.7018, Train Accuracy: 0.8092
# Epoch 15/100, Val Loss: 0.7996, Val AUC: 0.8981, Val Accuracy: 0.8685
# Epoch 16/100, Train Loss: 0.6869, Train Accuracy: 0.8099
# Epoch 16/100, Val Loss: 0.7847, Val AUC: 0.8984, Val Accuracy: 0.7682
# Epoch 17/100, Train Loss: 0.6839, Train Accuracy: 0.8150
# Epoch 17/100, Val Loss: 0.8574, Val AUC: 0.8889, Val Accuracy: 0.8727
# Epoch 18/100, Train Loss: 0.6781, Train Accuracy: 0.8158
# Epoch 18/100, Val Loss: 1.1268, Val AUC: 0.8289, Val Accuracy: 0.8809
# Epoch 19/100, Train Loss: 0.6704, Train Accuracy: 0.8261
# Epoch 19/100, Val Loss: 0.8025, Val AUC: 0.8971, Val Accuracy: 0.7929
# Epoch 20/100, Train Loss: 0.6631, Train Accuracy: 0.8164
# Epoch 20/100, Val Loss: 0.7590, Val AUC: 0.9099, Val Accuracy: 0.7760
# Best model saved for label HYP with AUC 0.9099
# Epoch 21/100, Train Loss: 0.6758, Train Accuracy: 0.8215
# Epoch 21/100, Val Loss: 0.7635, Val AUC: 0.8989, Val Accuracy: 0.8264
# Epoch 22/100, Train Loss: 0.6834, Train Accuracy: 0.8076
# Epoch 22/100, Val Loss: 0.7578, Val AUC: 0.9060, Val Accuracy: 0.8200
# Epoch 23/100, Train Loss: 0.6645, Train Accuracy: 0.8161
# Epoch 23/100, Val Loss: 0.7980, Val AUC: 0.8934, Val Accuracy: 0.8534
# Epoch 24/100, Train Loss: 0.6617, Train Accuracy: 0.8200
# Epoch 24/100, Val Loss: 1.0146, Val AUC: 0.8579, Val Accuracy: 0.8942
# Epoch 25/100, Train Loss: 0.6761, Train Accuracy: 0.8182
# Epoch 25/100, Val Loss: 0.7667, Val AUC: 0.9060, Val Accuracy: 0.8346
# Epoch 26/100, Train Loss: 0.6484, Train Accuracy: 0.8225
# Epoch 26/100, Val Loss: 0.7217, Val AUC: 0.9128, Val Accuracy: 0.7481
# Best model saved for label HYP with AUC 0.9128
# Epoch 27/100, Train Loss: 0.6551, Train Accuracy: 0.8162
# Epoch 27/100, Val Loss: 0.7803, Val AUC: 0.9042, Val Accuracy: 0.7925
# Epoch 28/100, Train Loss: 0.6592, Train Accuracy: 0.8225
# Epoch 47/100, Train Loss: 0.6203, Train Accuracy: 0.8297
# Epoch 47/100, Val Loss: 0.7569, Val AUC: 0.9054, Val Accuracy: 0.7678
# Epoch 48/100, Train Loss: 0.6250, Train Accuracy: 0.8262
# Epoch 48/100, Val Loss: 0.7437, Val AUC: 0.9022, Val Accuracy: 0.7893
# Epoch 49/100, Train Loss: 0.6299, Train Accuracy: 0.8254
# Epoch 49/100, Val Loss: 0.7810, Val AUC: 0.9014, Val Accuracy: 0.8044
# Epoch 50/100, Train Loss: 0.6170, Train Accuracy: 0.8309
# Epoch 50/100, Val Loss: 0.7595, Val AUC: 0.8977, Val Accuracy: 0.7916
# Epoch 51/100, Train Loss: 0.6196, Train Accuracy: 0.8293
# Epoch 51/100, Val Loss: 0.7214, Val AUC: 0.9095, Val Accuracy: 0.8191
# Epoch 52/100, Train Loss: 0.6180, Train Accuracy: 0.8292
# Epoch 52/100, Val Loss: 0.7443, Val AUC: 0.9062, Val Accuracy: 0.7490
# Epoch 53/100, Train Loss: 0.6124, Train Accuracy: 0.8268
# Epoch 53/100, Val Loss: 0.7573, Val AUC: 0.9087, Val Accuracy: 0.7989
# Epoch 54/100, Train Loss: 0.6165, Train Accuracy: 0.8265
# Epoch 54/100, Val Loss: 0.7570, Val AUC: 0.9119, Val Accuracy: 0.7687
# Epoch 55/100, Train Loss: 0.6132, Train Accuracy: 0.8274
# Epoch 55/100, Val Loss: 0.7347, Val AUC: 0.9014, Val Accuracy: 0.7888
# Epoch 56/100, Train Loss: 0.6026, Train Accuracy: 0.8309
# Epoch 56/100, Val Loss: 0.7344, Val AUC: 0.9129, Val Accuracy: 0.8172
# Best model saved for label HYP with AUC 0.9129
# Epoch 57/100, Train Loss: 0.6086, Train Accuracy: 0.8316
# Epoch 57/100, Val Loss: 0.7381, Val AUC: 0.9030, Val Accuracy: 0.7966
# Epoch 58/100, Train Loss: 0.6151, Train Accuracy: 0.8283
# Epoch 58/100, Val Loss: 0.7384, Val AUC: 0.9062, Val Accuracy: 0.7778
# Epoch 59/100, Train Loss: 0.6030, Train Accuracy: 0.8336
# Epoch 59/100, Val Loss: 0.7345, Val AUC: 0.8986, Val Accuracy: 0.7998
# Epoch 60/100, Train Loss: 0.6110, Train Accuracy: 0.8250
# Epoch 60/100, Val Loss: 0.7398, Val AUC: 0.9068, Val Accuracy: 0.8612
# Epoch 61/100, Train Loss: 0.6092, Train Accuracy: 0.8347
# Epoch 61/100, Val Loss: 0.7482, Val AUC: 0.9022, Val Accuracy: 0.7787
# Epoch 62/100, Train Loss: 0.6042, Train Accuracy: 0.8240
# Epoch 62/100, Val Loss: 1.1386, Val AUC: 0.8477, Val Accuracy: 0.8836
# Epoch 63/100, Train Loss: 0.5938, Train Accuracy: 0.8282
# Epoch 63/100, Val Loss: 0.7181, Val AUC: 0.9006, Val Accuracy: 0.8085
# Epoch 64/100, Train Loss: 0.6108, Train Accuracy: 0.8231
# Epoch 64/100, Val Loss: 0.7568, Val AUC: 0.9041, Val Accuracy: 0.8126
# Epoch 65/100, Train Loss: 0.6061, Train Accuracy: 0.8266
# Epoch 65/100, Val Loss: 0.7290, Val AUC: 0.9072, Val Accuracy: 0.7558
# Epoch 66/100, Train Loss: 0.5978, Train Accuracy: 0.8315
# Epoch 66/100, Val Loss: 0.7455, Val AUC: 0.9110, Val Accuracy: 0.7861
# Epoch 67/100, Train Loss: 0.6062, Train Accuracy: 0.8327
# Epoch 67/100, Val Loss: 0.7346, Val AUC: 0.9104, Val Accuracy: 0.7760
# Epoch 68/100, Train Loss: 0.6186, Train Accuracy: 0.8224
# Epoch 68/100, Val Loss: 0.7221, Val AUC: 0.9096, Val Accuracy: 0.8392
# Epoch 69/100, Train Loss: 0.5969, Train Accuracy: 0.8352
# Epoch 69/100, Val Loss: 0.7331, Val AUC: 0.9083, Val Accuracy: 0.8195
# Epoch 70/100, Train Loss: 0.6042, Train Accuracy: 0.8303
# Epoch 70/100, Val Loss: 0.6930, Val AUC: 0.9078, Val Accuracy: 0.8016
# Epoch 71/100, Train Loss: 0.5981, Train Accuracy: 0.8235
# Epoch 71/100, Val Loss: 0.7401, Val AUC: 0.9080, Val Accuracy: 0.8113
# Epoch 72/100, Train Loss: 0.6145, Train Accuracy: 0.8288
# Epoch 72/100, Val Loss: 0.7270, Val AUC: 0.9131, Val Accuracy: 0.7645
# Best model saved for label HYP with AUC 0.9131
# Epoch 73/100, Train Loss: 0.5980, Train Accuracy: 0.8333
# Epoch 73/100, Val Loss: 0.7414, Val AUC: 0.9074, Val Accuracy: 0.7430
# Epoch 74/100, Train Loss: 0.6044, Train Accuracy: 0.8263
# Epoch 74/100, Val Loss: 0.7161, Val AUC: 0.9033, Val Accuracy: 0.7577
# Epoch 75/100, Train Loss: 0.5957, Train Accuracy: 0.8303
# Epoch 75/100, Val Loss: 0.7424, Val AUC: 0.8951, Val Accuracy: 0.8246
# Epoch 76/100, Train Loss: 0.6107, Train Accuracy: 0.8301
# Epoch 76/100, Val Loss: 0.7116, Val AUC: 0.9094, Val Accuracy: 0.7980
# Epoch 77/100, Train Loss: 0.6007, Train Accuracy: 0.8306
# Epoch 77/100, Val Loss: 0.7045, Val AUC: 0.9077, Val Accuracy: 0.8067
# Epoch 78/100, Train Loss: 0.5862, Train Accuracy: 0.8358
# Epoch 78/100, Val Loss: 0.7031, Val AUC: 0.9065, Val Accuracy: 0.7975
# Epoch 79/100, Train Loss: 0.5859, Train Accuracy: 0.8305
# Epoch 79/100, Val Loss: 0.7676, Val AUC: 0.8963, Val Accuracy: 0.7668
# Epoch 80/100, Train Loss: 0.5914, Train Accuracy: 0.8345
# Epoch 80/100, Val Loss: 0.7986, Val AUC: 0.8939, Val Accuracy: 0.8630
# Epoch 81/100, Train Loss: 0.5925, Train Accuracy: 0.8298
# Epoch 81/100, Val Loss: 0.8034, Val AUC: 0.8865, Val Accuracy: 0.8296
# Epoch 82/100, Train Loss: 0.5994, Train Accuracy: 0.8267
# Epoch 82/100, Val Loss: 0.7571, Val AUC: 0.9059, Val Accuracy: 0.7018
# Epoch 83/100, Train Loss: 0.5847, Train Accuracy: 0.8281
# Epoch 83/100, Val Loss: 0.7585, Val AUC: 0.9034, Val Accuracy: 0.7256
# Epoch 84/100, Train Loss: 0.5957, Train Accuracy: 0.8314
# Epoch 84/100, Val Loss: 0.7134, Val AUC: 0.9037, Val Accuracy: 0.7879
# Epoch 85/100, Train Loss: 0.5927, Train Accuracy: 0.8291
# Epoch 85/100, Val Loss: 0.7250, Val AUC: 0.9042, Val Accuracy: 0.8071
# Epoch 86/100, Train Loss: 0.5784, Train Accuracy: 0.8360
# Epoch 86/100, Val Loss: 0.7585, Val AUC: 0.8919, Val Accuracy: 0.8291
# Epoch 87/100, Train Loss: 0.5891, Train Accuracy: 0.8298
# Epoch 87/100, Val Loss: 0.7195, Val AUC: 0.9067, Val Accuracy: 0.7430
# Epoch 88/100, Train Loss: 0.5968, Train Accuracy: 0.8304
# Epoch 88/100, Val Loss: 0.7152, Val AUC: 0.9044, Val Accuracy: 0.7966
# Epoch 89/100, Train Loss: 0.5840, Train Accuracy: 0.8274
# Epoch 89/100, Val Loss: 0.7347, Val AUC: 0.9065, Val Accuracy: 0.7668
# Epoch 90/100, Train Loss: 0.5962, Train Accuracy: 0.8345
# Epoch 90/100, Val Loss: 0.9036, Val AUC: 0.8692, Val Accuracy: 0.8781
# Epoch 91/100, Train Loss: 0.5829, Train Accuracy: 0.8371
# Epoch 91/100, Val Loss: 0.6904, Val AUC: 0.9145, Val Accuracy: 0.7829
# Best model saved for label HYP with AUC 0.9145
# Epoch 92/100, Train Loss: 0.5903, Train Accuracy: 0.8336
# Epoch 92/100, Val Loss: 0.7188, Val AUC: 0.9110, Val Accuracy: 0.7641
# Epoch 93/100, Train Loss: 0.5934, Train Accuracy: 0.8349
# Epoch 93/100, Val Loss: 0.7580, Val AUC: 0.9111, Val Accuracy: 0.7435
# Epoch 94/100, Train Loss: 0.5827, Train Accuracy: 0.8340
# Epoch 94/100, Val Loss: 0.6982, Val AUC: 0.9092, Val Accuracy: 0.7742
# Epoch 95/100, Train Loss: 0.5704, Train Accuracy: 0.8337
# Epoch 95/100, Val Loss: 0.7262, Val AUC: 0.9042, Val Accuracy: 0.7233
# Epoch 96/100, Train Loss: 0.5861, Train Accuracy: 0.8327
# Epoch 96/100, Val Loss: 0.7012, Val AUC: 0.9090, Val Accuracy: 0.7668
# Epoch 97/100, Train Loss: 0.5757, Train Accuracy: 0.8391
# Epoch 97/100, Val Loss: 0.7229, Val AUC: 0.9122, Val Accuracy: 0.7998
# Epoch 98/100, Train Loss: 0.5805, Train Accuracy: 0.8353
# Epoch 98/100, Val Loss: 0.7019, Val AUC: 0.9102, Val Accuracy: 0.8058
# Epoch 99/100, Train Loss: 0.5833, Train Accuracy: 0.8267
# Epoch 99/100, Val Loss: 0.7133, Val AUC: 0.9015, Val Accuracy: 0.7897
# Epoch 100/100, Train Loss: 0.5778, Train Accuracy: 0.8328
# Epoch 100/100, Val Loss: 0.7335, Val AUC: 0.8992, Val Accuracy: 0.8076
# Training completed for label: HYP. Best AUC: 0.9145
# =====================================================================
