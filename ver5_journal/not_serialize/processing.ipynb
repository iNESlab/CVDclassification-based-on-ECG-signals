# %%
import os

import pandas as pd
import torch

# %%
from dotenv import load_dotenv

# 현재 작업 디렉토리 가져오기
current_dir = os.getcwd()  # 현재 Jupyter Notebook의 작업 디렉토
env_path = os.path.join(current_dir, '../.env')

# .env 파일 로드
load_dotenv(env_path)
# Out:
# True

# %%
db_path=os.getenv("DATA_PATH")
ecg_data=pd.read_csv(f'{db_path}/ptbxl_database.csv')
ecg_data.head()
# Out:
#    ecg_id  patient_id   age  sex  height  weight  nurse  site     device  \
# 0       1     15709.0  56.0    1     NaN    63.0    2.0   0.0  CS-12   E
# 1       2     13243.0  19.0    0     NaN    70.0    2.0   0.0  CS-12   E
# 2       3     20372.0  37.0    1     NaN    69.0    2.0   0.0  CS-12   E
# 3       4     17014.0  24.0    0     NaN    82.0    2.0   0.0  CS-12   E
# 4       5     17448.0  19.0    1     NaN    70.0    2.0   0.0  CS-12   E
#
#         recording_date  ... validated_by_human  baseline_drift static_noise  \
# 0  1984-11-09 09:17:34  ...               True             NaN    , I-V1,
# 1  1984-11-14 12:55:37  ...               True             NaN          NaN
# 2  1984-11-15 12:49:10  ...               True             NaN          NaN
# 3  1984-11-15 13:44:57  ...               True    , II,III,AVF          NaN
# 4  1984-11-17 10:43:15  ...               True   , III,AVR,AVF          NaN
#
#   burst_noise electrodes_problems  extra_beats  pacemaker  strat_fold  \
# 0         NaN                 NaN          NaN        NaN           3
# 1         NaN                 NaN          NaN        NaN           2
# 2         NaN                 NaN          NaN        NaN           5
# 3         NaN                 NaN          NaN        NaN           3
# 4         NaN                 NaN          NaN        NaN           4
#
#                  filename_lr                filename_hr
# 0  records100/00000/00001_lr  records500/00000/00001_hr
# 1  records100/00000/00002_lr  records500/00000/00002_hr
# 2  records100/00000/00003_lr  records500/00000/00003_hr
# 3  records100/00000/00004_lr  records500/00000/00004_hr
# 4  records100/00000/00005_lr  records500/00000/00005_hr
#
# [5 rows x 28 columns]

# %% [markdown]
# ## 모델 및 하이퍼파라미터 준비
# BCResNet의 cnn_first의 stride나 다른 conv의 stride에 따라 입력 또는 출력의 크기가 달라짐.
# 이는 조절해가면서 실험필요

# %%
from ver4_journal.common.network.BCResNets import BCResNets

tau = 1
in_channel = 12
model = BCResNets(int(tau * 8), 5, in_channel)

if in_channel == 1:
    sample = torch.randn(1,12,1000)
else:
    sample = torch.randn(1,12,1000)
    #sample = torch.randn(1,12,20,48)

print(sample.shape)
pred = model(sample)
pred.shape
# Out:
# torch.Size([1, 12, 1000])
# torch.Size([1, 5])

# %%
from ver5_journal.common.data.create_final_data import create_final_data
from ver5_journal.common.data.ECG_Data import ECG_Data
from sklearn.metrics import roc_auc_score, accuracy_score
import torch
from torch.utils.data import DataLoader
import numpy as np
from ver5_journal.common.network.BCResNets import BCResNets

# 레이블 순서 : 데이터가 많은 순
label_columns = ['NORM', 'MI', 'STTC', 'CD', 'HYP']
num_epochs = 50

# train/val/test 분리
final_data = create_final_data()
ECG_train = final_data[final_data['strat_fold'].isin([1, 2, 3, 4, 5, 6, 7, 8])].reset_index(drop=True)
ECG_val = final_data[final_data['strat_fold'] == 9].reset_index(drop=True)
ECG_test = final_data[final_data['strat_fold'] == 10].reset_index(drop=True)

# Training 함수 정의
def train_one_epoch(model, train_loader, optimizer, loss_fn, device, label_idx):
    model.train()
    train_loss = 0
    y_true = []
    y_pred = []

    for data, label in train_loader:
        data, label = data.to(device), label.to(device)
        optimizer.zero_grad()

        output = model(data)
        label_data = label[:, label_idx].float().to(device)  # (batch_size)로 맞춤

        loss = loss_fn(torch.sigmoid(output).squeeze(-1), label_data)
        loss.backward()
        optimizer.step()

        train_loss += loss.item()

        # Accuracy 계산을 위해 예측값 저장
        y_true.extend(label_data.cpu().numpy())
        y_pred.extend((torch.sigmoid(output).detach().cpu().numpy() > 0.5).astype(int))  # 임계값 0.5 적용
    
    avg_loss = train_loss / len(train_loader)
    train_accuracy = accuracy_score(np.array(y_true), np.array(y_pred))  # 정확도 계산
    return avg_loss, train_accuracy

# Validation 함수 정의
def validate_one_epoch(model, val_loader, loss_fn, device, label_idx):
    model.eval()
    val_loss = 0
    y_true = []
    y_pred = []

    with torch.no_grad():
        for data, label in val_loader:
            data, label = data.to(device), label.to(device)

            output = model(data)
            label_data = label[:, label_idx].float().to(device)  # (batch_size)로 맞춤
            loss = loss_fn(torch.sigmoid(output).squeeze(-1), label_data)
            val_loss += loss.item()

            # AUC 및 Accuracy 계산을 위한 예측값 저장
            y_true.extend(label_data.cpu().numpy())
            y_pred.extend(torch.sigmoid(output).detach().cpu().numpy())

    avg_val_loss = val_loss / len(val_loader)
    val_auc = roc_auc_score(y_true, y_pred)
    val_accuracy = accuracy_score(np.array(y_true), (np.array(y_pred) > 0.5).astype(int))  # 정확도 계산
    return avg_val_loss, val_auc, val_accuracy

# %%
# 모델 학습 루프
for i, label in enumerate(label_columns):
    print(f"Training model for label: {label}")
    
    # 각 레이블에 대해 데이터 추출
    ECG_train_label = ECG_train[ECG_train[label].isin([0, 1])].reset_index(drop=True)
    ECG_val_label = ECG_val[ECG_val[label].isin([0, 1])].reset_index(drop=True)
    # ECG_test_label = ECG_test[ECG_test[label].isin([0, 1])].reset_index(drop=True)

    # 데이터 로더 준비
    train_dataset_label = ECG_Data(ECG_train_label)
    train_loader_label = DataLoader(train_dataset_label, batch_size=32, shuffle=True)

    val_dataset_label = ECG_Data(ECG_val_label)
    val_loader_label = DataLoader(val_dataset_label, batch_size=32, shuffle=True)

    # 모델 정의 및 학습
    device = torch.device("mps" if torch.backends.mps.is_available() else "cpu")
    model = BCResNets(16, 1, in_channel=12).to(device)

    optim = torch.optim.Adam(model.parameters(), lr=1e-2)
    loss_fn = torch.nn.BCELoss()

    best_val_auc = float('-inf')
    model_path = f'../common/best_models/{label}_model.pth'
    label_idx = label_columns.index(label)

    for epoch in range(num_epochs):
        # Training 단계
        train_loss, train_accuracy = train_one_epoch(model, train_loader_label, optim, loss_fn, device, label_idx)
        
        # Validation 단계
        val_loss, val_auc, val_accuracy = validate_one_epoch(model, val_loader_label, loss_fn, device,label_idx)
        
        print(f'Epoch {epoch+1}/{num_epochs}, Train Loss: {train_loss:.4f}, Train Accuracy: {train_accuracy:.4f}')
        print(f'Epoch {epoch+1}/{num_epochs}, Val Loss: {val_loss:.4f}, Val AUC: {val_auc:.4f}, Val Accuracy: {val_accuracy:.4f}')
        
        # 최적 AUC 모델 저장
        if val_auc > best_val_auc:
            best_val_auc = val_auc
            torch.save(model.state_dict(), model_path)
            print(f"Best model saved for label {label} with AUC {best_val_auc:.4f}")

    print(f"Training completed for label: {label}. Best AUC: {best_val_auc:.4f}")
    print("=====================================================================")
# Out:
# Training model for label: NORM
# Epoch 1/50, Train Loss: 0.4732, Train Accuracy: 0.7705
# Epoch 1/50, Val Loss: 0.4402, Val AUC: 0.9145, Val Accuracy: 0.8090
# Best model saved for label NORM with AUC 0.9145
# Epoch 2/50, Train Loss: 0.3708, Train Accuracy: 0.8329
# Epoch 2/50, Val Loss: 0.4295, Val AUC: 0.9186, Val Accuracy: 0.8342
# Best model saved for label NORM with AUC 0.9186
# Epoch 3/50, Train Loss: 0.3587, Train Accuracy: 0.8415
# Epoch 3/50, Val Loss: 0.3848, Val AUC: 0.9283, Val Accuracy: 0.8479
# Best model saved for label NORM with AUC 0.9283
# Epoch 4/50, Train Loss: 0.3450, Train Accuracy: 0.8503
# Epoch 4/50, Val Loss: 0.4028, Val AUC: 0.9279, Val Accuracy: 0.8191
# Epoch 5/50, Train Loss: 0.3393, Train Accuracy: 0.8516
# Epoch 5/50, Val Loss: 0.3946, Val AUC: 0.9277, Val Accuracy: 0.8465
# Epoch 6/50, Train Loss: 0.3301, Train Accuracy: 0.8549
# Epoch 6/50, Val Loss: 0.3446, Val AUC: 0.9373, Val Accuracy: 0.8552
# Best model saved for label NORM with AUC 0.9373
# Epoch 7/50, Train Loss: 0.3293, Train Accuracy: 0.8566
# Epoch 7/50, Val Loss: 0.4081, Val AUC: 0.9158, Val Accuracy: 0.8094
# Epoch 8/50, Train Loss: 0.3205, Train Accuracy: 0.8622
# Epoch 8/50, Val Loss: 0.3623, Val AUC: 0.9311, Val Accuracy: 0.8534
# Epoch 9/50, Train Loss: 0.3221, Train Accuracy: 0.8566
# Epoch 9/50, Val Loss: 0.3674, Val AUC: 0.9297, Val Accuracy: 0.8479
# Epoch 10/50, Train Loss: 0.3136, Train Accuracy: 0.8632
# Epoch 10/50, Val Loss: 0.3600, Val AUC: 0.9306, Val Accuracy: 0.8443
# Epoch 11/50, Train Loss: 0.3181, Train Accuracy: 0.8612
# Epoch 11/50, Val Loss: 0.3526, Val AUC: 0.9369, Val Accuracy: 0.8589
# Epoch 12/50, Train Loss: 0.3076, Train Accuracy: 0.8673
# Epoch 12/50, Val Loss: 0.3476, Val AUC: 0.9339, Val Accuracy: 0.8534
# Epoch 13/50, Train Loss: 0.3083, Train Accuracy: 0.8665
# Epoch 13/50, Val Loss: 0.3728, Val AUC: 0.9345, Val Accuracy: 0.8447
# Epoch 14/50, Train Loss: 0.3005, Train Accuracy: 0.8703
# Epoch 14/50, Val Loss: 0.3492, Val AUC: 0.9380, Val Accuracy: 0.8626
# Best model saved for label NORM with AUC 0.9380
# Epoch 49/50, Val Loss: 0.3449, Val AUC: 0.9378, Val Accuracy: 0.8543
# Epoch 50/50, Train Loss: 0.2639, Train Accuracy: 0.8874
# Epoch 50/50, Val Loss: 0.3365, Val AUC: 0.9407, Val Accuracy: 0.8594
# Training completed for label: NORM. Best AUC: 0.9440
# =====================================================================
# Training model for label: MI
# Epoch 1/50, Train Loss: 0.5143, Train Accuracy: 0.7662
# Epoch 1/50, Val Loss: 0.4308, Val AUC: 0.8294, Val Accuracy: 0.7975
# Best model saved for label MI with AUC 0.8294
# Epoch 2/50, Train Loss: 0.4122, Train Accuracy: 0.8140
# Epoch 2/50, Val Loss: 0.3910, Val AUC: 0.8687, Val Accuracy: 0.8342
# Best model saved for label MI with AUC 0.8687
# Epoch 3/50, Train Loss: 0.3773, Train Accuracy: 0.8356
# Epoch 3/50, Val Loss: 0.3864, Val AUC: 0.8934, Val Accuracy: 0.8456
# Best model saved for label MI with AUC 0.8934
# Epoch 4/50, Train Loss: 0.3486, Train Accuracy: 0.8525
# Epoch 4/50, Val Loss: 0.3507, Val AUC: 0.9075, Val Accuracy: 0.8658
# Best model saved for label MI with AUC 0.9075
# Epoch 5/50, Train Loss: 0.3277, Train Accuracy: 0.8600
# Epoch 5/50, Val Loss: 0.3928, Val AUC: 0.9026, Val Accuracy: 0.8186
# Epoch 6/50, Train Loss: 0.3180, Train Accuracy: 0.8674
# Epoch 6/50, Val Loss: 0.3384, Val AUC: 0.9142, Val Accuracy: 0.8717
# Best model saved for label MI with AUC 0.9142
# Epoch 7/50, Train Loss: 0.3053, Train Accuracy: 0.8727
# Epoch 7/50, Val Loss: 0.3418, Val AUC: 0.9139, Val Accuracy: 0.8736
# Epoch 8/50, Train Loss: 0.3009, Train Accuracy: 0.8732
# Epoch 8/50, Val Loss: 0.3750, Val AUC: 0.9205, Val Accuracy: 0.8749
# Best model saved for label MI with AUC 0.9205
# Epoch 9/50, Train Loss: 0.2967, Train Accuracy: 0.8763
# Epoch 9/50, Val Loss: 0.3635, Val AUC: 0.9176, Val Accuracy: 0.8708
# Epoch 10/50, Train Loss: 0.2926, Train Accuracy: 0.8793
# Epoch 10/50, Val Loss: 0.3101, Val AUC: 0.9213, Val Accuracy: 0.8713
# Best model saved for label MI with AUC 0.9213
# Epoch 11/50, Train Loss: 0.2925, Train Accuracy: 0.8771
# Epoch 11/50, Val Loss: 0.3345, Val AUC: 0.9224, Val Accuracy: 0.8713
# Best model saved for label MI with AUC 0.9224
# Epoch 12/50, Train Loss: 0.2930, Train Accuracy: 0.8791
# Epoch 12/50, Val Loss: 0.3258, Val AUC: 0.9189, Val Accuracy: 0.8759
# Epoch 13/50, Train Loss: 0.2904, Train Accuracy: 0.8808
# Epoch 13/50, Val Loss: 0.3330, Val AUC: 0.9165, Val Accuracy: 0.8676
# Epoch 14/50, Train Loss: 0.2815, Train Accuracy: 0.8845
# Epoch 14/50, Val Loss: 0.3298, Val AUC: 0.9218, Val Accuracy: 0.8749
# Best model saved for label MI with AUC 0.9320
# Epoch 50/50, Train Loss: 0.2402, Train Accuracy: 0.8997
# Epoch 50/50, Val Loss: 0.3193, Val AUC: 0.9318, Val Accuracy: 0.8754
# Training completed for label: MI. Best AUC: 0.9320
# =====================================================================
# Training model for label: STTC
# Epoch 1/50, Train Loss: 0.4425, Train Accuracy: 0.7999
# Epoch 1/50, Val Loss: 0.3531, Val AUC: 0.8986, Val Accuracy: 0.8383
# Best model saved for label STTC with AUC 0.8986
# Epoch 2/50, Train Loss: 0.3510, Train Accuracy: 0.8414
# Epoch 2/50, Val Loss: 0.3310, Val AUC: 0.9040, Val Accuracy: 0.8465
# Best model saved for label STTC with AUC 0.9040
# Epoch 3/50, Train Loss: 0.3354, Train Accuracy: 0.8497
# Epoch 3/50, Val Loss: 0.3171, Val AUC: 0.9171, Val Accuracy: 0.8667
# Best model saved for label STTC with AUC 0.9171
# Epoch 4/50, Train Loss: 0.3289, Train Accuracy: 0.8549
# Epoch 4/50, Val Loss: 0.3260, Val AUC: 0.9252, Val Accuracy: 0.8717
# Best model saved for label STTC with AUC 0.9252
# Epoch 5/50, Train Loss: 0.3270, Train Accuracy: 0.8554
# Epoch 5/50, Val Loss: 0.3272, Val AUC: 0.9203, Val Accuracy: 0.8644
# Epoch 6/50, Train Loss: 0.3225, Train Accuracy: 0.8585
# Epoch 6/50, Val Loss: 0.3218, Val AUC: 0.9167, Val Accuracy: 0.8667
# Epoch 7/50, Train Loss: 0.3157, Train Accuracy: 0.8613
# Epoch 7/50, Val Loss: 0.3218, Val AUC: 0.9118, Val Accuracy: 0.8548
# Epoch 8/50, Train Loss: 0.3151, Train Accuracy: 0.8615
# Epoch 8/50, Val Loss: 0.3082, Val AUC: 0.9255, Val Accuracy: 0.8598
# Best model saved for label STTC with AUC 0.9255
# Epoch 9/50, Train Loss: 0.3122, Train Accuracy: 0.8628
# Epoch 9/50, Val Loss: 0.3064, Val AUC: 0.9285, Val Accuracy: 0.8662
# Best model saved for label STTC with AUC 0.9285
# Epoch 10/50, Train Loss: 0.3080, Train Accuracy: 0.8653
# Epoch 10/50, Val Loss: 0.3433, Val AUC: 0.9243, Val Accuracy: 0.8690
# Epoch 11/50, Train Loss: 0.3083, Train Accuracy: 0.8665
# Epoch 11/50, Val Loss: 0.3094, Val AUC: 0.9274, Val Accuracy: 0.8763
# Epoch 12/50, Train Loss: 0.3045, Train Accuracy: 0.8670
# Epoch 12/50, Val Loss: 0.2952, Val AUC: 0.9242, Val Accuracy: 0.8658
# Epoch 13/50, Train Loss: 0.3034, Train Accuracy: 0.8669
# Epoch 13/50, Val Loss: 0.3160, Val AUC: 0.9300, Val Accuracy: 0.8777
# Best model saved for label STTC with AUC 0.9300
# Epoch 14/50, Train Loss: 0.3031, Train Accuracy: 0.8669
# Epoch 14/50, Val Loss: 0.3019, Val AUC: 0.9271, Val Accuracy: 0.8731
# Epoch 15/50, Train Loss: 0.2950, Train Accuracy: 0.8719
# Epoch 50/50, Val Loss: 0.2982, Val AUC: 0.9304, Val Accuracy: 0.8749
# Training completed for label: STTC. Best AUC: 0.9342
# =====================================================================
# Training model for label: CD
# Epoch 1/50, Train Loss: 0.4111, Train Accuracy: 0.8345
# Epoch 1/50, Val Loss: 0.3785, Val AUC: 0.8710, Val Accuracy: 0.8575
# Best model saved for label CD with AUC 0.8710
# Epoch 2/50, Train Loss: 0.3478, Train Accuracy: 0.8646
# Epoch 2/50, Val Loss: 0.3650, Val AUC: 0.8856, Val Accuracy: 0.8713
# Best model saved for label CD with AUC 0.8856
# Epoch 3/50, Train Loss: 0.3279, Train Accuracy: 0.8731
# Epoch 3/50, Val Loss: 0.3491, Val AUC: 0.8892, Val Accuracy: 0.8598
# Best model saved for label CD with AUC 0.8892
# Epoch 4/50, Train Loss: 0.3210, Train Accuracy: 0.8763
# Epoch 4/50, Val Loss: 0.3450, Val AUC: 0.9006, Val Accuracy: 0.8722
# Best model saved for label CD with AUC 0.9006
# Epoch 5/50, Train Loss: 0.3016, Train Accuracy: 0.8837
# Epoch 5/50, Val Loss: 0.3547, Val AUC: 0.9026, Val Accuracy: 0.8804
# Best model saved for label CD with AUC 0.9026
# Epoch 6/50, Train Loss: 0.2972, Train Accuracy: 0.8844
# Epoch 6/50, Val Loss: 0.3247, Val AUC: 0.9020, Val Accuracy: 0.8791
# Epoch 7/50, Train Loss: 0.2947, Train Accuracy: 0.8818
# Epoch 7/50, Val Loss: 0.3467, Val AUC: 0.9023, Val Accuracy: 0.8791
# Epoch 8/50, Train Loss: 0.2908, Train Accuracy: 0.8883
# Epoch 8/50, Val Loss: 0.3401, Val AUC: 0.9169, Val Accuracy: 0.8800
# Best model saved for label CD with AUC 0.9169
# Epoch 9/50, Train Loss: 0.2876, Train Accuracy: 0.8868
# Epoch 9/50, Val Loss: 0.3936, Val AUC: 0.9126, Val Accuracy: 0.8699
# Epoch 10/50, Train Loss: 0.2877, Train Accuracy: 0.8901
# Epoch 10/50, Val Loss: 0.3402, Val AUC: 0.9120, Val Accuracy: 0.8727
# Epoch 11/50, Train Loss: 0.2814, Train Accuracy: 0.8888
# Epoch 11/50, Val Loss: 0.4065, Val AUC: 0.9080, Val Accuracy: 0.8836
# Epoch 12/50, Train Loss: 0.2781, Train Accuracy: 0.8946
# Epoch 12/50, Val Loss: 0.3225, Val AUC: 0.9225, Val Accuracy: 0.8901
# Best model saved for label CD with AUC 0.9225
# Epoch 13/50, Train Loss: 0.2753, Train Accuracy: 0.8932
# Epoch 13/50, Val Loss: 0.3213, Val AUC: 0.9237, Val Accuracy: 0.8772
# Best model saved for label CD with AUC 0.9237
# Epoch 14/50, Train Loss: 0.2741, Train Accuracy: 0.8913
# Epoch 14/50, Val Loss: 0.3401, Val AUC: 0.9216, Val Accuracy: 0.8882
# Epoch 15/50, Train Loss: 0.2683, Train Accuracy: 0.8971
# Epoch 15/50, Val Loss: 0.3622, Val AUC: 0.9237, Val Accuracy: 0.8836
# Best model saved for label CD with AUC 0.9237
# Epoch 16/50, Train Loss: 0.2676, Train Accuracy: 0.8956
# Epoch 16/50, Val Loss: 0.3632, Val AUC: 0.9223, Val Accuracy: 0.8869
# Epoch 17/50, Train Loss: 0.2657, Train Accuracy: 0.8980
# Epoch 17/50, Val Loss: 0.3951, Val AUC: 0.9271, Val Accuracy: 0.8685
# Best model saved for label CD with AUC 0.9271
# Epoch 18/50, Train Loss: 0.2644, Train Accuracy: 0.8973
# Epoch 18/50, Val Loss: 0.3467, Val AUC: 0.9281, Val Accuracy: 0.8864
# Best model saved for label CD with AUC 0.9281
# Epoch 19/50, Train Loss: 0.2621, Train Accuracy: 0.8971
# Epoch 19/50, Val Loss: 0.4487, Val AUC: 0.9217, Val Accuracy: 0.8397
# Epoch 20/50, Train Loss: 0.2621, Train Accuracy: 0.8976
# Epoch 20/50, Val Loss: 0.3235, Val AUC: 0.9238, Val Accuracy: 0.8901
# Epoch 21/50, Train Loss: 0.2610, Train Accuracy: 0.8987
# Epoch 21/50, Val Loss: 0.3710, Val AUC: 0.9256, Val Accuracy: 0.8814
# Epoch 22/50, Train Loss: 0.2572, Train Accuracy: 0.8986
# Epoch 22/50, Val Loss: 0.3172, Val AUC: 0.9302, Val Accuracy: 0.8905
# Best model saved for label CD with AUC 0.9302
# Epoch 23/50, Train Loss: 0.2537, Train Accuracy: 0.9021
# Epoch 23/50, Val Loss: 0.3640, Val AUC: 0.9272, Val Accuracy: 0.8864
# Epoch 24/50, Train Loss: 0.2523, Train Accuracy: 0.9011
# Epoch 24/50, Val Loss: 0.3825, Val AUC: 0.9255, Val Accuracy: 0.8855
# Epoch 25/50, Train Loss: 0.2542, Train Accuracy: 0.9023
# Epoch 25/50, Val Loss: 0.3765, Val AUC: 0.9271, Val Accuracy: 0.8873
# Epoch 26/50, Train Loss: 0.2503, Train Accuracy: 0.9015
# Epoch 26/50, Val Loss: 0.3371, Val AUC: 0.9256, Val Accuracy: 0.8827
# Epoch 27/50, Train Loss: 0.2513, Train Accuracy: 0.9040
# Epoch 27/50, Val Loss: 0.3576, Val AUC: 0.9320, Val Accuracy: 0.8768
# Best model saved for label CD with AUC 0.9320
# Epoch 28/50, Train Loss: 0.2458, Train Accuracy: 0.9041
# Epoch 28/50, Val Loss: 0.3323, Val AUC: 0.9287, Val Accuracy: 0.8983
# Epoch 29/50, Train Loss: 0.2522, Train Accuracy: 0.8986
# Epoch 29/50, Val Loss: 0.3392, Val AUC: 0.9253, Val Accuracy: 0.8859
# Epoch 30/50, Train Loss: 0.2492, Train Accuracy: 0.9040
# Epoch 30/50, Val Loss: 0.3998, Val AUC: 0.9285, Val Accuracy: 0.8731
# Epoch 31/50, Train Loss: 0.2462, Train Accuracy: 0.9038
# Epoch 31/50, Val Loss: 0.4106, Val AUC: 0.9283, Val Accuracy: 0.8539
# Epoch 32/50, Train Loss: 0.2465, Train Accuracy: 0.9048
# Epoch 32/50, Val Loss: 0.3365, Val AUC: 0.9307, Val Accuracy: 0.8882
# Epoch 50/50, Val Loss: 0.3152, Val AUC: 0.9321, Val Accuracy: 0.8992
# Training completed for label: CD. Best AUC: 0.9333
# =====================================================================
# Training model for label: HYP
# Epoch 1/50, Train Loss: 0.2953, Train Accuracy: 0.8852
# Epoch 1/50, Val Loss: 0.2687, Val AUC: 0.8740, Val Accuracy: 0.8864
# Best model saved for label HYP with AUC 0.8740
# Epoch 2/50, Train Loss: 0.2495, Train Accuracy: 0.9001
# Epoch 2/50, Val Loss: 0.2731, Val AUC: 0.8760, Val Accuracy: 0.8969
# Best model saved for label HYP with AUC 0.8760
# Epoch 3/50, Train Loss: 0.2441, Train Accuracy: 0.9025
# Epoch 3/50, Val Loss: 0.2760, Val AUC: 0.8883, Val Accuracy: 0.9006
# Best model saved for label HYP with AUC 0.8883
# Epoch 4/50, Train Loss: 0.2389, Train Accuracy: 0.9071
# Epoch 4/50, Val Loss: 0.2484, Val AUC: 0.8956, Val Accuracy: 0.8974
# Best model saved for label HYP with AUC 0.8956
# Epoch 5/50, Train Loss: 0.2353, Train Accuracy: 0.9104
# Epoch 5/50, Val Loss: 0.2590, Val AUC: 0.8977, Val Accuracy: 0.8946
# Best model saved for label HYP with AUC 0.8977
# Epoch 6/50, Train Loss: 0.2390, Train Accuracy: 0.9063
# Epoch 6/50, Val Loss: 0.2765, Val AUC: 0.8937, Val Accuracy: 0.8841
# Epoch 7/50, Train Loss: 0.2353, Train Accuracy: 0.9089
# Epoch 7/50, Val Loss: 0.2391, Val AUC: 0.8993, Val Accuracy: 0.9029
# Best model saved for label HYP with AUC 0.8993
# Epoch 8/50, Train Loss: 0.2343, Train Accuracy: 0.9072
# Epoch 8/50, Val Loss: 0.2698, Val AUC: 0.8826, Val Accuracy: 0.8896
# Epoch 9/50, Train Loss: 0.2328, Train Accuracy: 0.9088
# Epoch 9/50, Val Loss: 0.2958, Val AUC: 0.8880, Val Accuracy: 0.8772
# Epoch 10/50, Train Loss: 0.2290, Train Accuracy: 0.9108
# Epoch 10/50, Val Loss: 0.2861, Val AUC: 0.8835, Val Accuracy: 0.8937
# Epoch 11/50, Train Loss: 0.2305, Train Accuracy: 0.9108
# Epoch 11/50, Val Loss: 0.2718, Val AUC: 0.8952, Val Accuracy: 0.8997
# Epoch 12/50, Train Loss: 0.2257, Train Accuracy: 0.9106
# Epoch 12/50, Val Loss: 0.2594, Val AUC: 0.8820, Val Accuracy: 0.9006
# Epoch 13/50, Train Loss: 0.2236, Train Accuracy: 0.9132
# Epoch 13/50, Val Loss: 0.2423, Val AUC: 0.8936, Val Accuracy: 0.8974
# Epoch 14/50, Train Loss: 0.2270, Train Accuracy: 0.9107
# Epoch 14/50, Val Loss: 0.2654, Val AUC: 0.8750, Val Accuracy: 0.8960
# Epoch 15/50, Train Loss: 0.2265, Train Accuracy: 0.9115
# Epoch 15/50, Val Loss: 0.2847, Val AUC: 0.8789, Val Accuracy: 0.8937
# Epoch 34/50, Train Loss: 0.2096, Train Accuracy: 0.9171
# Epoch 34/50, Val Loss: 0.2439, Val AUC: 0.8956, Val Accuracy: 0.9024
# Epoch 35/50, Train Loss: 0.2105, Train Accuracy: 0.9168
# Epoch 35/50, Val Loss: 0.2655, Val AUC: 0.8723, Val Accuracy: 0.8951
# Epoch 36/50, Train Loss: 0.2109, Train Accuracy: 0.9183
# Epoch 36/50, Val Loss: 0.2719, Val AUC: 0.9010, Val Accuracy: 0.8992
# Epoch 37/50, Train Loss: 0.2076, Train Accuracy: 0.9162
# Epoch 37/50, Val Loss: 0.2507, Val AUC: 0.9091, Val Accuracy: 0.9102
# Best model saved for label HYP with AUC 0.9091
# Epoch 38/50, Train Loss: 0.2088, Train Accuracy: 0.9175
# Epoch 38/50, Val Loss: 0.2501, Val AUC: 0.9013, Val Accuracy: 0.9038
# Epoch 39/50, Train Loss: 0.2052, Train Accuracy: 0.9188
# Epoch 39/50, Val Loss: 0.2556, Val AUC: 0.9016, Val Accuracy: 0.9093
# Epoch 40/50, Train Loss: 0.2057, Train Accuracy: 0.9164
# Epoch 40/50, Val Loss: 0.2595, Val AUC: 0.9109, Val Accuracy: 0.9116
# Best model saved for label HYP with AUC 0.9109
# Epoch 41/50, Train Loss: 0.2057, Train Accuracy: 0.9194
# Epoch 41/50, Val Loss: 0.2617, Val AUC: 0.8914, Val Accuracy: 0.9061
# Epoch 42/50, Train Loss: 0.2057, Train Accuracy: 0.9173
# Epoch 42/50, Val Loss: 0.2416, Val AUC: 0.9077, Val Accuracy: 0.9093
# Epoch 43/50, Train Loss: 0.2068, Train Accuracy: 0.9194
# Epoch 43/50, Val Loss: 0.2505, Val AUC: 0.9023, Val Accuracy: 0.9084
# Epoch 44/50, Train Loss: 0.2043, Train Accuracy: 0.9191
# Epoch 44/50, Val Loss: 0.2544, Val AUC: 0.9038, Val Accuracy: 0.9088
# Epoch 45/50, Train Loss: 0.2060, Train Accuracy: 0.9180
# Epoch 45/50, Val Loss: 0.2713, Val AUC: 0.8894, Val Accuracy: 0.9052
# Epoch 46/50, Train Loss: 0.2047, Train Accuracy: 0.9196
# Epoch 46/50, Val Loss: 0.2586, Val AUC: 0.9103, Val Accuracy: 0.9139
# Epoch 47/50, Train Loss: 0.2074, Train Accuracy: 0.9176
# Epoch 47/50, Val Loss: 0.2590, Val AUC: 0.8929, Val Accuracy: 0.9070
# Epoch 48/50, Train Loss: 0.2054, Train Accuracy: 0.9187
# Epoch 48/50, Val Loss: 0.2782, Val AUC: 0.9044, Val Accuracy: 0.9098
# Epoch 49/50, Train Loss: 0.2022, Train Accuracy: 0.9188
# Epoch 49/50, Val Loss: 0.2981, Val AUC: 0.8992, Val Accuracy: 0.9079
# Epoch 50/50, Train Loss: 0.2047, Train Accuracy: 0.9192
# Epoch 50/50, Val Loss: 0.2647, Val AUC: 0.8972, Val Accuracy: 0.9102
# Training completed for label: HYP. Best AUC: 0.9109
# =====================================================================
